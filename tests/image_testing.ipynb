# %%
from astrosceni.image import Image

# %%
img1 = Image('data/rim_R_wcs.fits')
img2 = Image('data/rim_Ha_wcs.fits')

# %%
img2.plot(original=True)
# img2.cropPixels(x_end=-20, y_start=20)
img2.cropPixels(x_end=-20, y_start=20)
img2.plot()

# %%
img2.plot(original=True)
img2.cropCoords(ra_end='18h25m40s', dec_start='-12d24m', original=True)
img2.plot()

# %%
result = Image.subtract(img2, img1, mu=0.1)
result.plot()

# %%
from astrosceni.stars_filter import StarsFilter
filter = StarsFilter()
filter.setCatalogue("I/259/tyc2", ra_col_name="RA_ICRS_", dec_col_name="DE_ICRS_", app_mag_col_name="VTmag")
filter.setMagLimit(None, 11)
filter.setVisibleStars(img1)


img1.setLabeledStars(filter)
img1.plot()
# Out:
# Previous saved catalog file not found
# Obtaining copy of catalogue from online
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/pracs/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'RA_ICRS_'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 5
#       3 filter.setCatalogue("I/259/tyc2", ra_col_name="RA_ICRS_", dec_col_name="DE_ICRS_", app_mag_col_name="VTmag")
#       4 filter.setMagLimit(None, 11)
# ----> 5 filter.setVisibleStars(img1)
#       8 img1.setLabeledStars(filter)
#       9 img1.plot()
#
# File ~/Desktop/code/summer-scholarship/paddy/astrosceni/stars_filter.py:149, in StarsFilter.setVisibleStars(self, image)
#     146     self.dec_max = max(decCorners)
#     148 #Create a copy of the catalog DF where the only stars remaining are those that are within the bounds set by the image
# --> 149 catalog_df = catalog_df[(catalog_df[self.ra_col_name] >= self.ra_min) &
#     150                         (catalog_df[self.ra_col_name] <= self.ra_max) &
#     151                         (catalog_df[self.dec_col_name] >= self.dec_min) &
#     152                         (catalog_df[self.dec_col_name] <= self.dec_max)]
#     154 #Save the coordinates of the filtered catalog and their unit (degrees) within a SkyCoord object
#     155 star_coords = SkyCoord(ra = catalog_df[self.ra_col_name], dec = catalog_df[self.dec_col_name], unit = 'deg')
#
# File ~/anaconda3/envs/pracs/lib/python3.11/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/anaconda3/envs/pracs/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'RA_ICRS_'

# %%
# img1.plot(original=True)
img1.cropCoords(ra_end='18h28m40s', dec_start='-13d24m', original=True)
img1.plot(original=True, showCropped=True, croppedBorder='cyan')

# img2.plot(original=True)
# img2.cropCoords(ra_start='18h32m40s', dec_end='-13d20m', original=True) # Should be no overlap
img2.cropCoords(ra_start='18h32m40s', dec_end='-13d40m', original=True) # Should be overlap
img2.plot(original=True, showCropped=True, croppedBorder='cyan')

val = Image.overlap(img1, img2)

print(val)
print(val[0])

if corners:
  print("Corners: ", corners)

  # import matplotlib.pyplot as plt
  # plt.scatter(corners[0], corners[1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 8
#       5 # img2.plot(original=True)
#       6 # img2.cropCoords(ra_start='18h32m40s', dec_end='-13d20m', original=True) # Should be no overlap
#       7 img2.cropCoords(ra_start='18h32m40s', dec_end='-13d40m', original=True) # Should be overlap
# ----> 8 img2.plot(original=True, showCropped=True, croppedBorder='cyan')
#      10 val = Image.overlap(img1, img2)
#      12 print(val)
#
# File ~/Desktop/code/summer-scholarship/paddy/astrosceni/image.py:267, in Image.plot(self, original, showCropped, croppedBorder, circleSize)
#     264 if showCropped and self.cutout:
#     265   self.cutout.plot_on_original(color=croppedBorder)
# --> 267 if self.labeled_starts is not None:
#     268   self.labeled_starts.apply(lambda star: ax.add_patch(plt.Circle((star['x_pixels'], star['y_pixels']), circleSize, color='b', fill=False)), axis=1)
#     269   # for _, star in self.labeled_starts.iterrows():
#     270     # ax.add_patch(plt.Circle((star['x_pixels'], star['y_pixels']), circleSize, color='b', fill=False))
#
# AttributeError: 'Image' object has no attribute 'labeled_starts'
