# %%
from astrosceni.image import Image

# %%
img2 = Image()
img2.load("data/rim_Ha_wcs.fits")
img2._printData()
# Out:
# [[ 135.  145.  142. ...  140.  133.  135.]
#  [ 280.  276.  283. ...  546.  286.  135.]
#  [ 706.  697.  700. ...  569.  272.  140.]
#  ...
#  [3434. 3423. 3453. ...  705.  421.  138.]
#  [3464. 3478. 3504. ...  702.  423.  133.]
#  [3593. 3581. 3495. ...  718.  412.  136.]]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59846.552361 from DATE-OBS'. [astropy.wcs.wcs]

# %%
# img2.plot(original=True)
# # img2.cropPixels(x_end=-20, y_start=20)
# img2.cropPixels(x_end=-20, y_start=20)
# img2.plot()

# %%
img2.plot(original=True)
# img2.cropPixels(x_end=-20, y_start=20)
img2.cropCoords(ra_end='18h24m', dec_start='-12d24m', original=True)
img2.plot()
# Out:
# ra_start 280.2947545909179 ra_end 276.3393541418493 dec_start -12.267334351386697 dec_end -14.502011827669545
# (array(1045.56601268), array(692.52765962))
# (1390.9999999774163, 2078.9999999836477)
